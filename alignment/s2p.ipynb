# %%
from pathlib import Path
from tempfile import TemporaryDirectory

import matplotlib.pyplot as plt
import numpy as np
import sys
import suite2p

# %%
sys.path.insert(0, 'C:/Users/carse/github/suite2p/')
from suite2p import default_ops

# set your options for running
ops = default_ops() # populates ops with the default options
ops['denoise']=True
ops['norm_frames']=False
ops['batch_size']=80
ops['fs']=30
ops['tau'] = 0.7
ops['soma_crop']=False
ops['use_builtin_classifier']=True
ops['threshold_scaling']=0.8
ops['max_overlap'] = 0.5
ops['min_SNR'] = 2
ops['anatomical_only'] = 2
ops['soma_crop']=1
ops['functional_chan'] = 2
ops['bruker'] = True


db = {
    'data_path': ['Z:/All_Staff/Lab data/Ben/Water reaching/imaging/11242025/TSeries-11242025-BY31-002'],
    'save_path0': 'Z:/All_Staff/Lab data/Ben/Water reaching/imaging/11242025/TSeries-11242025-BY31-002/output',
}

# %%
output_ops = suite2p.run_s2p(ops=ops, db=db)
# Out:
# {'data_path': ['Z:/All_Staff/Lab data/Ben/Water reaching/imaging/11242025/TSeries-11242025-BY31-002'], 'save_path0': 'Z:/All_Staff/Lab data/Ben/Water reaching/imaging/11242025/TSeries-11242025-BY31-002/output'}
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 output_ops = suite2p.run_s2p(ops=ops, db=db)
#
# File c:\Users\16344\anaconda3\envs\suite2p\lib\site-packages\suite2p\run_s2p.py:408, in run_s2p(ops, db, server)
#     406     ops["save_folder"] = "suite2p"
#     407 save_folder = os.path.join(ops["save_path0"], ops["save_folder"])
# --> 408 os.makedirs(save_folder, exist_ok=True)
#     409 plane_folders = natsorted([
#     410     f.path for f in os.scandir(save_folder) if f.is_dir() and f.name[:5] == "plane"
#     411 ])
#     413 if len(plane_folders) > 0 and (ops.get("input_format") and ops["input_format"]=="binary"):
# ...
